# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
file_path=r'C:\Users\SHRI\Documents\DS\EDA\Visadataset.csv'
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_path=r'C:\Users\SHRI\Documents\DS\EDA\bank.csv'
pd.read_csv(file_path)
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
##To seperate the data in columns use ( sep=';' ) 

file_path=r'C:\Users\SHRI\Documents\DS\EDA\bank.csv'
bankdf=pd.read_csv(file_path,sep=';')
bankdf
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
- shape

- size

- len

- columns

- dtypes

- isnull

- head

- tail

- info

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
len(visa_df)
# Out:
# 25480

# %%
visa_df.size
# Out:
# 305760

# %%
visa_df.head(5)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.tail(10)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25470                     N             2272         1970
# ...

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **task 1**
#
# - i want to seperate the cat and numerical columns
#
# - cat columns in one list
#
# - NUmerical columns in another list

# %%
visa_df.dtypes.keys()     ## visa_df.dtypes.keys().tolist()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.dtypes.values    ## visa_df.dtypes.values.tolist()
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
#cols,dtypes

for i in dtype:
    if i == 'object':
        print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 3
#       1 #cols,dtypes
# ----> 3 for i in dtype:
#       4     if i == 'object':
#       5         print(i)
#
# NameError: name 'dtype' is not defined

# %%
cat=[]
numerical=[]
for i,j in zip(dtypes,cols):
    if j == 'object':
        cat.append(i)
    else:
        numerical.append(i)

print(cat)
print(numerical)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 cat=[]
#       2 numerical=[]
# ----> 3 for i,j in zip(dtypes,cols):
#       4     if j == 'object':
#       5         cat.append(i)
#
# NameError: name 'dtypes' is not defined

# %%
cat=[j for i,j in zip (dtypes, cols)  if i =='object']
numerical=[j for i,j in zip (dtypes, cols)  if i !='object']
len(cat), len(numerical)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 cat=[j for i,j in zip (dtypes, cols)  if i =='object']
#       2 numerical=[j for i,j in zip (dtypes, cols)  if i !='object']
#       3 len(cat), len(numerical)
#
# NameError: name 'dtypes' is not defined

# %%
visa_df
visa_df.dtypes
visa_df.dtypes.keys()
cols=visa_df.dtypes.keys().tolist()
dtypes=visa_df.dtypes.values.tolist()

# %% [markdown]
# ## select dtypes

# %%
cat=visa_df.select_dtypes(include= 'object')   ## short cut for it

# %%
catr=visa_df.select_dtypes(include= 'object').columns
numerical=visa_df.select_dtypes(exclude= 'object').columns  ## for numerical
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 catr=visa_df.select_dtypes(include= 'object').columns
#       2 numerical=visa_df.select_dtypes(exclude= 'object').columns
#
# NameError: name 'visa_df' is not defined

# %% [markdown]
# **task 2 : covert series to dataframe**

# %%
dtypes = visa_df.dtypes
d1=pd.DataFrame(dtypes,columns=['data type'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dtypes = visa_df.dtypes
#       2 pd.DataFrame(dtypes,columns=['data type'])
#
# NameError: name 'visa_df' is not defined

# %%
dtypes = visa_df.dtypes
d1=pd.DataFrame(dtypes,columns=['data type'])
d1.reset_index().rename({'index':'Column'})     ## series to data frame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 dtypes = visa_df.dtypes
#       2 d1=pd.DataFrame(dtypes,columns=['data type'])
#       3 d1.reset_index().rename({'index':'Column'})
#
# NameError: name 'visa_df' is not defined

# %%
visa_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 visa_
#
# NameError: name 'visa_' is not defined

# %%
visa_df.dtype.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 visa_df.dtype.index
#
# NameError: name 'visa_df' is not defined

# %%
visa_df.dtype.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 visa_df.dtype.keys
#
# NameError: name 'visa_df' is not defined

# %%
key = value
index= values

# %%
dict(visa_df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 dict(visa_df.dtypes)
#
# NameError: name 'visa_df' is not defined

# %% [markdown]
# **another method**

# %%
#### Another method

## if i have a two list can i create 
# 
cols=visa_df.dtypes.index.tolist()
dtypes=visa_df.values.tolist()
pd.DataFrame(zip(cols,dtype))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       1 #### Another method
#       2
#       3 ## if i have a two list can i create
#       4 #
# ----> 5 cols=visa_df.dtypes.index.tolist()
#       6 dtypes=visa_df.values.tolist()
#       7 pd.DataFrame(zip(cols,dtype))
#
# NameError: name 'visa_df' is not defined

# %% [markdown]
# ## Selection of Data

# %%
visa_df.iloc[rows,columns]

visa_df.iloc[St:stp:end , St:stp:end]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 visa_df.iloc[rows,columns]
#
# NameError: name 'visa_df' is not defined

# %%
visa_df
## 100-105 row     100,101,102,103,104 ##  middle of rows to extract i want
## 3 : 6     3,4,5  
visa_df.iloc[100 : 105 , 3: 6]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 visa_df
#       2 ## 100-105 row     100,101,102,103,104 ##  middle of rows to extract i want
#       3 ## 3 : 6     3,4,5
#       4 visa_df.iloc[100 : 105 , 3: 6]
#
# NameError: name 'visa_df' is not defined

# %%
visa_df.iloc[100 : 105 , 3: 6]   # 100 to 104 rows from 3 to 5 columns
visa_df.iloc[100 : 105 ]         # 100 to 104 rows fro all columns
visa_df.iloc[100]                # 100th rows series
visa_df.iloc[[100]]              # 100th row df
visa_df.iloc[[100,200,300]]           ## there is no order here we can dosplay ranmdomly rows
visa_df.iloc[[100,200,300] , 3 : 6]     ## only 3,6
visa_df.iloc[[100,200,300] , [1,5,9]]   ## 1st , 5th , 9th  column

## check it all do practice

# %%
cols.index('unit_of_wage')    ##  write column name directly and find number of column

# %%
## replace iloc  by loc
## use directly column names here 
visa_df.loc[[100,200,300] , ['continent','no_of_employees','unit_of_wage']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 ## replace iloc  by loc
#       2 ## use directly column names here
# ----> 3 visa_df.loc[[100,200,300] , ['continent','no_of_employees','unit_of_wage']]
#
# NameError: name 'visa_df' is not defined
